# %%
import networkx as nx

# %%
g = nx.read_edgelist('0.edges')

# %%
list(g.node)
# Out:
# ['236',
#  '186',
#  '122',
#  '285',
#  '24',
#  '346',
#  '271',
#  '304',
#  '176',
#  '9',
#  '130',
#  '329',
#  '204',
#  '213',
#  '252',
#  '332',
#  '82',
#  '65',
#  '276',
#  '26',
#  '280',
#  '272',
#  '211',
#  '199',
#  '84',
#  '133',
#  '62',
#  '239',
#  '172',
#  '322',
#  '53',
#  '3',
#  '170',
#  '175',
#  '46',
#  '56',
#  '254',
#  '194',
#  '231',
#  '117',
#  '127',
#  '135',
#  '103',
#  '188',
#  '23',
#  '116',
#  '73',
#  '299',
#  '288',
#  '315',
#  '119',
#  '323',
#  '48',
#  '57',
#  '200',
#  '98',
#  '313',
#  '63',
#  '344',
#  '67',
#  '118',
#  '325',
#  '277',
#  '134',
#  '270',
#  '76',
#  '36',
#  '223',
#  '274',
#  '88',
#  '21',
#  '339',
#  '108',
#  '197',
#  '169',
#  '275',
#  '273',
#  '83',
#  '28',
#  '312',
#  '242',
#  '214',
#  '20',
#  '307',
#  '71',
#  '333',
#  '207',
#  '168',
#  '308',
#  '341',
#  '128',
#  '334',
#  '238',
#  '265',
#  '141',
#  '78',
#  '345',
#  '317',
#  '158',
#  '38',
#  '302',
#  '27',
#  '54',
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
s = np.random.poisson(lam=(100., 500.), size=(333, 2))

# %%
s
# Out:
# array([[107, 534],
#        [ 96, 531],
#        [139, 487],
#        [ 86, 489],
#        [ 94, 494],
#        [ 99, 496],
#        [ 90, 454],
#        [103, 498],
#        [106, 517],
#        [ 90, 505],
#        [ 92, 523],
#        [102, 515],
#        [103, 498],
#        [113, 512],
#        [102, 516],
#        [ 93, 519],
#        [ 87, 482],
#        [105, 506],
#        [103, 521],
#        [ 96, 499],
#        [ 92, 517],
#        [ 94, 494],
#        [107, 497],
#        [ 91, 518],
#        [117, 519],
#        [ 90, 497],
#        [ 95, 494],
#        [112, 484],
#        [ 92, 529],
#        [ 99, 503],
#        [ 92, 490],
#        [100, 500],
#        [ 94, 461],
#        [ 95, 495],
#        [107, 495],
#        [102, 479],
#        [ 97, 506],
#        [116, 488],
#        [109, 545],
#        [102, 535],
#        [100, 446],
#        [ 97, 531],
#        [103, 497],
#        [108, 498],
#        [ 97, 527],
#        [106, 474],
#        [109, 487],
# ...

# %%
keys = list(g.node)

# %%
pos = dict(zip(keys, s))

# %%
pos
# Out:
# {'1': array([103, 464]),
#  '10': array([111, 504]),
#  '100': array([107, 508]),
#  '101': array([114, 510]),
#  '102': array([ 93, 524]),
#  '103': array([103, 497]),
#  '104': array([107, 537]),
#  '105': array([ 94, 508]),
#  '106': array([ 93, 514]),
#  '107': array([104, 478]),
#  '108': array([108, 530]),
#  '109': array([105, 484]),
#  '110': array([115, 492]),
#  '111': array([ 71, 497]),
#  '112': array([123, 466]),
#  '113': array([ 74, 483]),
#  '115': array([ 82, 529]),
#  '116': array([106, 474]),
#  '117': array([102, 535]),
#  '118': array([118, 490]),
#  '119': array([105, 514]),
#  '120': array([ 84, 482]),
#  '121': array([ 88, 507]),
#  '122': array([139, 487]),
#  '123': array([ 95, 495]),
#  '124': array([100, 503]),
#  '125': array([110, 476]),
#  '126': array([ 80, 497]),
#  '127': array([100, 446]),
#  '128': array([111, 453]),
#  '129': array([102, 555]),
#  '13': array([101, 551]),
#  '130': array([ 92, 523]),
#  '131': array([100, 492]),
# ...

# %%
nx.draw(g,node_size=5, pos = dict(zip(keys, s)), edge_color='y',with_labels=False,linewidths=0,font_size=20)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
pos
# Out:
# {'1': array([103, 464]),
#  '10': array([111, 504]),
#  '100': array([107, 508]),
#  '101': array([114, 510]),
#  '102': array([ 93, 524]),
#  '103': array([103, 497]),
#  '104': array([107, 537]),
#  '105': array([ 94, 508]),
#  '106': array([ 93, 514]),
#  '107': array([104, 478]),
#  '108': array([108, 530]),
#  '109': array([105, 484]),
#  '110': array([115, 492]),
#  '111': array([ 71, 497]),
#  '112': array([123, 466]),
#  '113': array([ 74, 483]),
#  '115': array([ 82, 529]),
#  '116': array([106, 474]),
#  '117': array([102, 535]),
#  '118': array([118, 490]),
#  '119': array([105, 514]),
#  '120': array([ 84, 482]),
#  '121': array([ 88, 507]),
#  '122': array([139, 487]),
#  '123': array([ 95, 495]),
#  '124': array([100, 503]),
#  '125': array([110, 476]),
#  '126': array([ 80, 497]),
#  '127': array([100, 446]),
#  '128': array([111, 453]),
#  '129': array([102, 555]),
#  '13': array([101, 551]),
#  '130': array([ 92, 523]),
#  '131': array([100, 492]),
# ...

# %%
plt.show()

# %%
pos
# Out:
# {'1': array([103, 464]),
#  '10': array([111, 504]),
#  '100': array([107, 508]),
#  '101': array([114, 510]),
#  '102': array([ 93, 524]),
#  '103': array([103, 497]),
#  '104': array([107, 537]),
#  '105': array([ 94, 508]),
#  '106': array([ 93, 514]),
#  '107': array([104, 478]),
#  '108': array([108, 530]),
#  '109': array([105, 484]),
#  '110': array([115, 492]),
#  '111': array([ 71, 497]),
#  '112': array([123, 466]),
#  '113': array([ 74, 483]),
#  '115': array([ 82, 529]),
#  '116': array([106, 474]),
#  '117': array([102, 535]),
#  '118': array([118, 490]),
#  '119': array([105, 514]),
#  '120': array([ 84, 482]),
#  '121': array([ 88, 507]),
#  '122': array([139, 487]),
#  '123': array([ 95, 495]),
#  '124': array([100, 503]),
#  '125': array([110, 476]),
#  '126': array([ 80, 497]),
#  '127': array([100, 446]),
#  '128': array([111, 453]),
#  '129': array([102, 555]),
#  '13': array([101, 551]),
#  '130': array([ 92, 523]),
#  '131': array([100, 492]),
# ...

# %%
c = list(nx.k_clique_communities(g, 4))

# %%
len(c)
# Out:
# 9

# %%
c[0]
# Out:
# frozenset({'1',
#            '10',
#            '100',
#            '101',
#            '103',
#            '104',
#            '105',
#            '106',
#            '108',
#            '109',
#            '113',
#            '118',
#            '119',
#            '121',
#            '122',
#            '123',
#            '126',
#            '127',
#            '128',
#            '129',
#            '13',
#            '130',
#            '132',
#            '133',
#            '134',
#            '135',
#            '136',
#            '139',
#            '141',
#            '142',
#            '146',
#            '148',
#            '150',
#            '156',
#            '158',
#            '159',
#            '16',
#            '161',
#            '163',
#            '165',
#            '168',
#            '169',
#            '170',
#            '171',
#            '172',
#            '176',
#            '178',
#            '180',
#            '184',
#            '185',
# ...

# %%
h = g.subgraph(c[0])

# %%
c[0]
# Out:
# frozenset({'1',
#            '10',
#            '100',
#            '101',
#            '103',
#            '104',
#            '105',
#            '106',
#            '108',
#            '109',
#            '113',
#            '118',
#            '119',
#            '121',
#            '122',
#            '123',
#            '126',
#            '127',
#            '128',
#            '129',
#            '13',
#            '130',
#            '132',
#            '133',
#            '134',
#            '135',
#            '136',
#            '139',
#            '141',
#            '142',
#            '146',
#            '148',
#            '150',
#            '156',
#            '158',
#            '159',
#            '16',
#            '161',
#            '163',
#            '165',
#            '168',
#            '169',
#            '170',
#            '171',
#            '172',
#            '176',
#            '178',
#            '180',
#            '184',
#            '185',
# ...

# %%
nx.draw(h,node_size=15, edge_color='y',with_labels=False,linewidths=0,font_size=20)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
plt.show()

# %%
l = g.subgraph(c[7])

# %%
nx.draw(l,node_size=15, edge_color='y',with_labels=True,linewidths=0,font_size=20)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
plt.show()

# %% [markdown]
# c[2]

# %%
c[2]
# Out:
# frozenset({'147', '219', '319', '327', '6', '89', '95'})

# %%
h1 = g.subgraph(c[1])

# %%
nx.draw(h1, node_size=15, edge_color='y',with_labels=False,linewidths=0,font_size=20)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
plt.show()

# %%
c[3]
# Out:
# frozenset({'102',
#            '131',
#            '143',
#            '175',
#            '177',
#            '225',
#            '227',
#            '23',
#            '263',
#            '278',
#            '296',
#            '46',
#            '68',
#            '86',
#            '99'})

# %%
h2 = g.subgraph(c[8])

# %%
nx.draw(h2, node_size=15, edge_color='y',with_labels=True,linewidths=0,font_size=20)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\User\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
plt.show()

# %%
list(c[5])
# Out:
# ['51', '84', '31', '237', '83', '23', '25']

# %%
c[6]
# Out:
# frozenset({'115', '220', '262', '312'})

# %% [markdown]
# c[4]

# %%
c[4]
# Out:
# frozenset({'152', '181', '195', '218', '273', '275', '306', '328', '4', '78'})

# %%
c[1]
# Out:
# frozenset({'111',
#            '115',
#            '116',
#            '137',
#            '14',
#            '140',
#            '144',
#            '149',
#            '151',
#            '162',
#            '167',
#            '17',
#            '19',
#            '2',
#            '20',
#            '214',
#            '226',
#            '243',
#            '28',
#            '310',
#            '312',
#            '32',
#            '326',
#            '333',
#            '337',
#            '343',
#            '41',
#            '44',
#            '93'})

# %%
posshar = np.random.poisson(lam=(3., 3.), size=(333, 2))

# %%
posshar
# Out:
# array([[3, 1],
#        [3, 4],
#        [3, 3],
#        [3, 2],
#        [4, 3],
#        [0, 7],
#        [2, 6],
#        [2, 2],
#        [2, 2],
#        [6, 4],
#        [2, 5],
#        [4, 2],
#        [3, 4],
#        [3, 2],
#        [4, 5],
#        [5, 2],
#        [2, 3],
#        [4, 2],
#        [5, 0],
#        [3, 2],
#        [5, 3],
#        [3, 5],
#        [3, 3],
#        [4, 3],
#        [5, 4],
#        [3, 4],
#        [2, 2],
#        [6, 2],
#        [2, 7],
#        [4, 5],
#        [1, 8],
#        [1, 1],
#        [1, 6],
#        [4, 2],
#        [5, 2],
#        [3, 2],
#        [4, 0],
#        [7, 4],
#        [3, 1],
#        [2, 2],
#        [4, 5],
#        [2, 4],
#        [1, 2],
#        [5, 4],
#        [4, 4],
#        [5, 6],
#        [2, 3],
#        [3, 2],
#        [3, 5],
#        [3, 2],
#        [4, 5],
#        [1, 0],
#        [1, 3],
#        [1, 8],
#        [2, 1],
#        [4, 3],
#        [6, 3],
#        [5, 5],
# ...

# %%
ps = dict(zip(keys, posshar))

# %%
ps
# Out:
# {'1': array([7, 3]),
#  '10': array([1, 5]),
#  '100': array([2, 0]),
#  '101': array([6, 1]),
#  '102': array([3, 2]),
#  '103': array([1, 2]),
#  '104': array([4, 1]),
#  '105': array([5, 4]),
#  '106': array([1, 3]),
#  '107': array([3, 2]),
#  '108': array([3, 2]),
#  '109': array([1, 8]),
#  '110': array([3, 5]),
#  '111': array([4, 2]),
#  '112': array([3, 4]),
#  '113': array([2, 3]),
#  '115': array([6, 1]),
#  '116': array([5, 6]),
#  '117': array([2, 2]),
#  '118': array([4, 4]),
#  '119': array([4, 5]),
#  '120': array([1, 3]),
#  '121': array([3, 1]),
#  '122': array([3, 3]),
#  '123': array([4, 4]),
#  '124': array([1, 1]),
#  '125': array([3, 3]),
#  '126': array([2, 3]),
#  '127': array([4, 5]),
#  '128': array([3, 8]),
#  '129': array([5, 3]),
#  '13': array([1, 2]),
#  '130': array([2, 5]),
#  '131': array([7, 2]),
#  '132': array([3, 6]),
#  '133': array([3, 4]),
#  '134': array([3, 5]),
#  '135': array([2, 4]),
#  '136': array([4, 0]),
#  '137': array([2, 5]),
# ...

# %%
for keys in ps:
    ps[keys] = [0.5*ps[keys][0]+ 0.5*ps[keys][1]]

# %%
ps
# Out:
# {'1': [5.0],
#  '10': [3.0],
#  '100': [1.0],
#  '101': [3.5],
#  '102': [2.5],
#  '103': [1.5],
#  '104': [2.5],
#  '105': [4.5],
#  '106': [2.0],
#  '107': [2.5],
#  '108': [2.5],
#  '109': [4.5],
#  '110': [4.0],
#  '111': [3.0],
#  '112': [3.5],
#  '113': [2.5],
#  '115': [3.5],
#  '116': [5.5],
#  '117': [2.0],
#  '118': [4.0],
#  '119': [4.5],
#  '120': [2.0],
#  '121': [2.0],
#  '122': [3.0],
#  '123': [4.0],
#  '124': [1.0],
#  '125': [3.0],
#  '126': [2.5],
#  '127': [4.5],
#  '128': [5.5],
#  '129': [4.0],
#  '13': [1.5],
#  '130': [3.5],
#  '131': [4.5],
#  '132': [4.5],
#  '133': [3.5],
#  '134': [4.0],
#  '135': [3.0],
#  '136': [2.0],
#  '137': [3.5],
#  '138': [2.0],
#  '139': [4.0],
#  '14': [4.5],
#  '140': [2.0],
#  '141': [4.5],
#  '142': [2.5],
#  '143': [3.5],
#  '144': [4.0],
#  '145': [2.5],
#  '146': [4.0],
#  '147': [2.5],
#  '148': [3.5],
#  '149': [2.0],
#  '150': [3.0],
#  '151': [4.0],
#  '152': [2.0],
#  '153': [3.0],
#  '154': [1.0],
#  '155': [1.0],
# ...

# %%
socialactive = [keys for keys in ps if ps[keys][0]>=5]

# %%
socialactive
# Out:
# ['9', '194', '116', '63', '83', '128', '64', '1', '156', '338', '314', '95']

# %%
b1 = list(c[0])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 9

# %%
b1 = list(c[1])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 1

# %%
b1 = list(c[2])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 1

# %%
b1 = list(c[3])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 0

# %%
b1 = list(c[4])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 0

# %%
b1 = list(c[5])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 1

# %%
b1 = list(c[6])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 0

# %%
b1 = list(c[7])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 0

# %%
b1 = list(c[8])
b2 = list(socialactive)
b3=list(set(b1).intersection(b2))
len(b3)
# Out:
# 1

# %%
su=0
for keys in list(c[0]):
    su= su+ps[keys][0]
su
# Out:
# 569.0

# %%
su1=0
for keys in list(c[1]):
    su1= su1+ps[keys][0]
su1
# Out:
# 80.5

# %%
su2=0
for keys in list(c[2]):
    su2= su2+ps[keys][0]
su2
# Out:
# 22.0

# %%
su3=0
for keys in list(c[3]):
    su3= su3+ps[keys][0]
su3
# Out:
# 46.5

# %%
su4=0
for keys in list(c[4]):
    su4= su4+ps[keys][0]
su4
# Out:
# 29.5

# %%
su5=0
for keys in list(c[5]):
    su5= su5+ps[keys][0]
su5
# Out:
# 27.0

# %%
su6=0
for keys in list(c[6]):
    su6= su6+ps[keys][0]
su6
# Out:
# 10.0

# %%
su7=0
for keys in list(c[7]):
    su7= su7+ps[keys][0]
su7
# Out:
# 20.0

# %%
su8=0
for keys in list(c[8]):
    su8= su8+ps[keys][0]
su8
# Out:
# 14.0

# %%
from scipy.stats import spearmanr

# %%
x=[0,1,3,2,5,7,4,8,6]
y=[0,1,4,8,6,3,2,5,7]
spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=0.43333333333333335, pvalue=0.24395243588005161)

# %%
spearmanr(x)
# Out:
# SpearmanrResult(correlation=1.0, pvalue=0.0)
